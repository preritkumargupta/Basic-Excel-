# %% [markdown]
# 1.Explain the difference between Relative , Absolute and Mixed Cell Referencing.
# You have the following dataset: [Data Link](https://github.com/preritkumargupta/Basic-Excel-/blob/main/Untitled%20spreadsheet%20-%20Sheet1.pdf)
#
# - Relative Reference (A1)
#
# Changes automatically when you copy the formula.
#
# Example: =A1 + B1
#
# If copied down, it becomes =A2 + B2.
#
# - Absolute Reference ($A$1)
#
#
# Does NOT change when copied.
#
# $ locks the row and column.
#
# Example: =$A$1 * B1
#
# - Mixed Reference ($A1 or A$1)
# Only one part is fixed.
#
# $A1 → column A locked
#
# A$1 → row 1 locked
#
#  2.Write a formula to calculate the total sales of Car and Bicyle only.
#
#   - =SUM(D3:D4)
#
#    3.Using the data below, write a formula to calculate the average sales of items priced above 100 but less than
# 300:
# [DataSet Link](https://github.com/preritkumargupta/Basic-Excel-/blob/main/Untitled%20spreadsheet%20-%20Sheet1%20(1).pdf)
#
# - Average sales of items priced >100 and <300
#
# - Example
#   - Price Column = B
#
#   - Sales Column = C
#
# - Fromula:   =AVERAGEIFS(C:C, B:B, ">100", B:B, "<300")

# %% [markdown]
# # New Section
